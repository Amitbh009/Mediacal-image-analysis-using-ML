# %% [markdown]
# Survey paper : https://link.springer.com/article/10.1007/s40747-021-00563-y
#
# Dataset link : https://www.kaggle.com/datasets/masoudnickparvar/brain-tumor-mri-dataset/suggestions

# %%
#no need to run this as dataset is already in the repo in dataset folder
import kagglehub

# Download latest version
path = kagglehub.dataset_download("masoudnickparvar/brain-tumor-mri-dataset")

print("Path to dataset files:", path)

# %%
# !pip3 install -q medpy tqdm joblib

# %%
# !python3
